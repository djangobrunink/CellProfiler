# %% [markdown]
# # Training

# %%
import os

if "models" in os.getcwd():
    os.chdir("..")

if "notebooks" in os.getcwd():
    os.chdir("..")
os.getcwd()
# Out:
# '/home/jordi/Documents/GitHub/zebra_fish'

# %%
from src.dataset import register_default_datasets
from src.LrFinder import LRFinder
from src.hooks.LossEvalHook import LossEvalHook
from src.hooks.PredictionVisualHook import PredictionVisualHook
from src.hooks.ConfusionHook import ConfusionHook
from src.RandomZoom import RandomZoom

#detectron
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.utils.logger import setup_logger
from detectron2.data import DatasetCatalog, build_detection_test_loader, build_detection_train_loader, DatasetMapper, detection_utils as utils, transforms as T
from detectron2.utils.events import CommonMetricPrinter, JSONWriter, TensorboardXWriter
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.engine import CallbackHook
from detectron2.engine.hooks import HookBase
from detectron2.utils.events import EventStorage
import detectron2.utils.comm as comm
from detectron2.utils.logger import log_every_n_seconds
from detectron2.utils.visualizer import Visualizer
import matplotlib.pyplot as plt
from pathlib import Path

import time
import datetime
import torch
import numpy as np
import gc

register_default_datasets(clear=True)

# %%
class CustomTrainer(DefaultTrainer):

    def __init__(self, cfg):
        super().__init__(cfg)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
            os.makedirs(output_folder, exist_ok=True)
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(-1, LossEvalHook.create(self.cfg))
        hooks.insert(-1, PredictionVisualHook.create(self.cfg)),
        #hooks.insert(-1, ConfusionHook.create(self.cfg, threshold=0.75))
        
        return hooks
    
    @classmethod
    def build_train_loader(cls, cfg):
        augmentations = [
            T.RandomRotation([0, 360], expand=False, center=[[0.45, 0.45], [0.55, 0.55]], sample_style="range"),
            RandomZoom([[x, x] for x in np.linspace(0.5, 0.95, 10)], prob=0.25),
            T.RandomFlip(prob=0.5, horizontal=True),
            T.ResizeShortestEdge(short_edge_length=cfg.INPUT.MIN_SIZE_TRAIN, max_size=cfg.INPUT.MAX_SIZE_TRAIN, sample_style=cfg.INPUT.MIN_SIZE_TRAIN_SAMPLING),
        ]
        mapper = DatasetMapper(
            is_train=True,
            augmentations=augmentations,
            image_format=cfg.INPUT.FORMAT,
            use_instance_mask=cfg.MODEL.MASK_ON,
            instance_mask_format=cfg.INPUT.MASK_FORMAT,
            use_keypoint=cfg.MODEL.KEYPOINT_ON,
            recompute_boxes=True,
        )

        return build_detection_train_loader(cfg, mapper=mapper)
    
    @classmethod
    def build_lr_scheduler(cls, cfg, optimizer):
        return torch.optim.lr_scheduler.OneCycleLR(
            optimizer,
            max_lr=cfg.SOLVER.BASE_LR,
            total_steps=cfg.SOLVER.MAX_ITER,
            final_div_factor=25,
            div_factor=25,
        )
    
    def find_lr(self):
        finder = LRFinder()
        
        with EventStorage(0) as self.storage:
            res = finder.find(
                self.model,
                self.optimizer,
                self.build_train_loader(self.cfg),
            )
        
        return res

# %%
# Default config
use_collapsed = True
cfg = get_cfg()
#cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("train",) if not use_collapsed else ("train_collapsed",)
cfg.DATASETS.TEST = ("val",) if not use_collapsed else ("val_collapsed",)
meta_dataset = MetadataCatalog.get(cfg.DATASETS.TRAIN[0])
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(meta_dataset.thing_classes)


print(meta_dataset.thing_classes)

cfg.MODEL.WEIGHTS = str(Path("./outputs/new_dataset/res101_fr2_no_problamatic_10000_random_zoom/model_final.pth"))
cfg.SOLVER.CHECKPOINT_PERIOD = 250
cfg.SOLVER.MAX_ITER = 5000
cfg.TEST.EVAL_PERIOD = 40
cfg.OUTPUT_DIR = "./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk"
cfg.MODEL.BACKBONE.FREEZE_AT = 2
cfg.SOLVER.WARMUP_ITERS = 0
if cfg.SOLVER.WARMUP_ITERS > 0:
    cfg.SOLVER.WARMUP_FACTOR = 1.0 / cfg.SOLVER.WARMUP_ITERS

# Hyper-params
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.MODEL.RPN.NMS_THRESH = 0.70
cfg.SOLVER.WEIGHT_DECAY = 0.001
cfg.SOLVER.BASE_LR =  0.0012328467394420682



#cfg.MODEL.ANCHOR_GENERATOR.ASPECT_RATIOS = [[0.25, 0.5, 1.0, 2, 4]]
#cfg.INPUT.MIN_SIZE_TRAIN = (1333, 1333)
#cfg.INPUT.MAX_SIZE_TRAIN = 1333
#cfg.INPUT.MIN_SIZE_TEST = (1333, 1333)
#cfg.INPUT.MAX_SIZE_TEST = 1333
cfg.MODEL.RPN.LOSS_WEIGHT = 2.0
#cfg.MODEL.RESNETS.NORM = "BN"

assert cfg.TEST.EVAL_PERIOD % 20 == 0, "EVAL_PERIOD must be a multiple of 20"
# Out:
# ['Healthy', 'Deformed', 'Death', 'Yolk']

# %%
resume = True
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
assert resume or len(os.listdir(cfg.OUTPUT_DIR))  == 0, "Output dir is not empty!"

trainer = CustomTrainer(cfg)
trainer.resume_or_load(resume=resume)



with open(Path(cfg.OUTPUT_DIR) / "config.yaml", "w") as f:
    f.write(cfg.dump())
# Out:
# [08/18 14:29:39 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (predictor): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [08/18 14:29:39 d2.data.dataset_mapper]: Augmentations used in training: [RandomRotation(angle=[0, 360], expand=False, center=[[0.45, 0.45], [0.55, 0.55]]), RandomZoom(zooms=[[0.5, 0.5],
#  [0.55, 0.55],
#  [0.6, 0.6],
#  [0.65, 0.65],
#  [0.7, 0.7],
#  [0.75, 0.75],
#  [0.8, 0.8],
#  [0.85, 0.85],
#  [0.8999999999999999, 0.8999999999999999],
#  [0.95, 0.95]], prob=0.25), RandomFlip(prob=0.5), ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice')]
# [08/18 14:29:41 d2.data.build]: Removed 0 images with no usable annotations. 51 images left.
# [08/18 14:29:41 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |  Healthy   | 387          |  Deformed  | 72           |   Death    | 61           |
# |    Yolk    | 452          |            |              |            |              |
# |   total    | 972          |            |              |            |              |
# [08/18 14:29:41 d2.data.common]: Serializing 51 elements to byte tensors and concatenating them all ...
# [08/18 14:29:41 d2.data.common]: Serialized dataset takes 0.49 MiB
# [08/18 14:29:41 d2.data.build]: Using training sampler TrainingSampler
# [08/18 14:29:41 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:29:41 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |  Healthy   | 114          |  Deformed  | 16           |   Death    | 16           |
# |    Yolk    | 128          |            |              |            |              |
# |   total    | 274          |            |              |            |              |
# [08/18 14:29:41 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:29:41 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:29:42 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:29:42 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:29:42 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (4, 1024) in the checkpoint but (5, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (4,) in the checkpoint but (5,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (12, 1024) in the checkpoint but (16, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (12,) in the checkpoint but (16,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (3, 256, 1, 1) in the checkpoint but (4, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (3,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.

# %%
trainer.train()
# Out:
# [08/18 14:29:42 d2.engine.train_loop]: Starting training from iteration 0
# [08/18 14:29:52 d2.utils.events]:  eta: 0:37:10  iter: 19  total_loss: 3.722  loss_cls: 1.178  loss_box_reg: 0.870  loss_mask: 0.635  loss_rpn_cls: 0.735  loss_rpn_loc: 0.346  time: 0.4491  data_time: 0.0181  lr: 0.000050  max_mem: 3856M
# [08/18 14:30:01 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:30:01 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:30:01 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:30:01 d2.evaluation.coco_evaluation]: 'val_collapsed' is not registered by `register_coco_instances`. Therefore trying to convert it to COCO format ...
# [08/18 14:30:01 d2.data.datasets.coco]: Converting annotations of dataset 'val_collapsed' to COCO format ...)
# [08/18 14:30:01 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [08/18 14:30:01 d2.data.datasets.coco]: Conversion finished, #images: 14, #annotations: 274
# [08/18 14:30:01 d2.data.datasets.coco]: Caching COCO format annotations at './outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/val_collapsed_coco_format.json' ...
# [08/18 14:30:01 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:30:07 d2.evaluation.evaluator]: Inference done 11/14. 0.1105 s / img. ETA=0:00:01
# [08/18 14:30:08 d2.evaluation.evaluator]: Total inference time: 0:00:04.150056 (0.461117 s / img per device, on 1 devices)
# [08/18 14:30:08 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.103154 s / img per device, on 1 devices)
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.135
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.212
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.385
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 14.002 | 25.805 | 13.487 | 0.000 | 21.225 | 12.821 |
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP    | category   | AP    |
# |:-----------|:-------|:-----------|:------|:-----------|:------|
# | Healthy    | 51.286 | Deformed   | 4.142 | Death      | 0.487 |
# | Yolk       | 0.094  |            |       |            |       |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.022
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 1.074 | 5.133  | 0.000  | 0.000 | 1.327 | 1.371 |
# [08/18 14:30:08 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP    | category   | AP    | category   | AP    |
# |:-----------|:------|:-----------|:------|:-----------|:------|
# | Healthy    | 4.291 | Deformed   | 0.000 | Death      | 0.000 |
# | Yolk       | 0.006 |            |       |            |       |
# [08/18 14:30:08 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: 14.0021,25.8048,13.4872,0.0000,21.2252,12.8210
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:30:08 d2.evaluation.testing]: copypaste: 1.0742,5.1329,0.0000,0.0000,1.3272,1.3715
# @@@ Evaluation @@@ 39
# [08/18 14:30:10 d2.utils.events]:  eta: 0:36:27  iter: 39  total_loss: 2.855  loss_cls: 0.766  loss_box_reg: 0.809  loss_mask: 0.548  loss_rpn_cls: 0.314  loss_rpn_loc: 0.338  validation_loss: 2.613  time: 0.4441  data_time: 0.0028  lr: 0.000051  max_mem: 4187M
# [08/18 14:30:19 d2.utils.events]:  eta: 0:36:16  iter: 59  total_loss: 2.476  loss_cls: 0.737  loss_box_reg: 0.777  loss_mask: 0.486  loss_rpn_cls: 0.173  loss_rpn_loc: 0.283  validation_loss: 2.613  time: 0.4387  data_time: 0.0029  lr: 0.000054  max_mem: 4187M
# [08/18 14:30:28 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:30:28 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:30:28 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:30:28 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:30:37 d2.evaluation.evaluator]: Inference done 11/14. 0.1509 s / img. ETA=0:00:02
# [08/18 14:30:38 d2.evaluation.evaluator]: Total inference time: 0:00:06.907173 (0.767464 s / img per device, on 1 devices)
# [08/18 14:30:38 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.135011 s / img per device, on 1 devices)
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.363
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 17.129 | 35.190 | 14.680 | 5.714 | 24.756 | 15.424 |
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP    | category   | AP     |
# |:-----------|:-------|:-----------|:------|:-----------|:-------|
# | Healthy    | 48.639 | Deformed   | 2.921 | Death      | 15.685 |
# | Yolk       | 1.269  |            |       |            |        |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.184
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.110
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.140
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 13.179 | 25.201 | 13.870 | 1.573 | 18.354 | 11.039 |
# [08/18 14:30:38 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP    | category   | AP    |
# |:-----------|:-------|:-----------|:------|:-----------|:------|
# | Healthy    | 50.262 | Deformed   | 0.000 | Death      | 1.193 |
# | Yolk       | 1.262  |            |       |            |       |
# [08/18 14:30:38 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: 17.1285,35.1898,14.6797,5.7144,24.7559,15.4243
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:30:38 d2.evaluation.testing]: copypaste: 13.1792,25.2014,13.8696,1.5733,18.3536,11.0391
# @@@ Evaluation @@@ 79
# [08/18 14:30:45 d2.utils.events]:  eta: 0:35:39  iter: 79  total_loss: 2.164  loss_cls: 0.574  loss_box_reg: 0.755  loss_mask: 0.432  loss_rpn_cls: 0.126  loss_rpn_loc: 0.324  validation_loss: 2.363  time: 0.4363  data_time: 0.0029  lr: 0.000057  max_mem: 4187M
# [08/18 14:30:56 d2.utils.events]:  eta: 0:35:55  iter: 99  total_loss: 2.097  loss_cls: 0.498  loss_box_reg: 0.765  loss_mask: 0.403  loss_rpn_cls: 0.125  loss_rpn_loc: 0.281  validation_loss: 2.363  time: 0.4384  data_time: 0.0042  lr: 0.000062  max_mem: 4187M
# [08/18 14:31:05 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:31:05 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:31:05 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:31:05 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:31:15 d2.evaluation.evaluator]: Inference done 11/14. 0.1468 s / img. ETA=0:00:02
# [08/18 14:31:16 d2.evaluation.evaluator]: Total inference time: 0:00:06.923889 (0.769321 s / img per device, on 1 devices)
# [08/18 14:31:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.136171 s / img per device, on 1 devices)
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.241
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.203
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.434
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 24.095 | 46.208 | 22.398 | 6.329 | 25.131 | 24.759 |
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 55.677 | Deformed   | 18.102 | Death      | 20.952 |
# | Yolk       | 1.650  |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.214
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 18.284 | 35.912 | 20.706 | 2.182 | 20.568 | 17.612 |
# [08/18 14:31:16 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP    |
# |:-----------|:-------|:-----------|:-------|:-----------|:------|
# | Healthy    | 51.840 | Deformed   | 13.515 | Death      | 5.914 |
# | Yolk       | 1.867  |            |        |            |       |
# [08/18 14:31:16 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: 24.0954,46.2075,22.3976,6.3290,25.1310,24.7594
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:31:16 d2.evaluation.testing]: copypaste: 18.2840,35.9120,20.7059,2.1818,20.5678,17.6118
# @@@ Evaluation @@@ 119
# [08/18 14:31:18 d2.utils.events]:  eta: 0:35:34  iter: 119  total_loss: 1.951  loss_cls: 0.446  loss_box_reg: 0.694  loss_mask: 0.370  loss_rpn_cls: 0.113  loss_rpn_loc: 0.246  validation_loss: 2.113  time: 0.4379  data_time: 0.0029  lr: 0.000068  max_mem: 4187M
# [08/18 14:31:27 d2.utils.events]:  eta: 0:35:40  iter: 139  total_loss: 1.897  loss_cls: 0.418  loss_box_reg: 0.661  loss_mask: 0.350  loss_rpn_cls: 0.107  loss_rpn_loc: 0.296  validation_loss: 2.113  time: 0.4382  data_time: 0.0034  lr: 0.000074  max_mem: 4187M
# [08/18 14:31:37 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:31:37 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:31:37 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:31:37 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:31:45 d2.evaluation.evaluator]: Inference done 11/14. 0.1322 s / img. ETA=0:00:02
# [08/18 14:31:46 d2.evaluation.evaluator]: Total inference time: 0:00:06.190925 (0.687881 s / img per device, on 1 devices)
# [08/18 14:31:46 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.122931 s / img per device, on 1 devices)
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.369
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.530
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 31.576 | 54.171 | 35.340 | 8.507 | 36.934 | 31.704 |
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 64.818 | Deformed   | 26.688 | Death      | 32.488 |
# | Yolk       | 2.310  |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.228
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.271
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 22.836 | 45.138 | 25.685 | 3.341 | 25.506 | 21.975 |
# [08/18 14:31:46 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP    |
# |:-----------|:-------|:-----------|:-------|:-----------|:------|
# | Healthy    | 53.278 | Deformed   | 25.623 | Death      | 9.641 |
# | Yolk       | 2.804  |            |        |            |       |
# [08/18 14:31:46 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: 31.5759,54.1713,35.3398,8.5075,36.9342,31.7040
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:31:46 d2.evaluation.testing]: copypaste: 22.8362,45.1377,25.6853,3.3410,25.5063,21.9754
# @@@ Evaluation @@@ 159
# [08/18 14:31:53 d2.utils.events]:  eta: 0:35:50  iter: 159  total_loss: 1.783  loss_cls: 0.407  loss_box_reg: 0.647  loss_mask: 0.323  loss_rpn_cls: 0.106  loss_rpn_loc: 0.275  validation_loss: 1.988  time: 0.4445  data_time: 0.0032  lr: 0.000082  max_mem: 4187M
# [08/18 14:32:04 d2.utils.events]:  eta: 0:35:37  iter: 179  total_loss: 1.611  loss_cls: 0.366  loss_box_reg: 0.593  loss_mask: 0.322  loss_rpn_cls: 0.085  loss_rpn_loc: 0.261  validation_loss: 1.988  time: 0.4427  data_time: 0.0045  lr: 0.000090  max_mem: 4187M
# [08/18 14:32:14 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:32:14 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:32:14 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:32:14 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:32:22 d2.evaluation.evaluator]: Inference done 11/14. 0.1231 s / img. ETA=0:00:02
# [08/18 14:32:23 d2.evaluation.evaluator]: Total inference time: 0:00:05.702481 (0.633609 s / img per device, on 1 devices)
# [08/18 14:32:23 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.116603 s / img per device, on 1 devices)
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.572
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 35.688 | 62.726 | 37.924 | 15.775 | 42.100 | 34.180 |
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 69.794 | Deformed   | 38.972 | Death      | 28.913 |
# | Yolk       | 5.071  |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.251
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.393
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 25.120 | 51.259 | 28.648 | 3.834 | 27.139 | 24.455 |
# [08/18 14:32:23 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP    |
# |:-----------|:-------|:-----------|:-------|:-----------|:------|
# | Healthy    | 52.746 | Deformed   | 36.510 | Death      | 7.163 |
# | Yolk       | 4.061  |            |        |            |       |
# [08/18 14:32:23 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: 35.6877,62.7259,37.9236,15.7750,42.0997,34.1796
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:32:23 d2.evaluation.testing]: copypaste: 25.1200,51.2591,28.6477,3.8337,27.1395,24.4552
# @@@ Evaluation @@@ 199
# [08/18 14:32:25 d2.utils.events]:  eta: 0:35:28  iter: 199  total_loss: 1.604  loss_cls: 0.370  loss_box_reg: 0.586  loss_mask: 0.311  loss_rpn_cls: 0.103  loss_rpn_loc: 0.234  validation_loss: 1.863  time: 0.4441  data_time: 0.0027  lr: 0.000100  max_mem: 4260M
# [08/18 14:32:33 d2.utils.events]:  eta: 0:35:14  iter: 219  total_loss: 1.582  loss_cls: 0.347  loss_box_reg: 0.567  loss_mask: 0.306  loss_rpn_cls: 0.078  loss_rpn_loc: 0.235  validation_loss: 1.863  time: 0.4435  data_time: 0.0031  lr: 0.000111  max_mem: 4260M
# [08/18 14:32:43 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:32:43 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:32:43 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:32:43 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:32:50 d2.evaluation.evaluator]: Inference done 11/14. 0.1377 s / img. ETA=0:00:02
# [08/18 14:32:51 d2.evaluation.evaluator]: Total inference time: 0:00:05.484539 (0.609393 s / img per device, on 1 devices)
# [08/18 14:32:51 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.126396 s / img per device, on 1 devices)
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 37.318 | 60.734 | 41.645 | 16.823 | 46.222 | 35.654 |
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 73.798 | Deformed   | 38.064 | Death      | 29.882 |
# | Yolk       | 7.528  |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.063
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.257
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.329
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 25.760 | 53.017 | 28.027 | 6.272 | 26.610 | 25.655 |
# [08/18 14:32:51 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP    |
# |:-----------|:-------|:-----------|:-------|:-----------|:------|
# | Healthy    | 53.348 | Deformed   | 34.967 | Death      | 8.920 |
# | Yolk       | 5.805  |            |        |            |       |
# [08/18 14:32:51 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: 37.3178,60.7341,41.6454,16.8227,46.2216,35.6536
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:32:51 d2.evaluation.testing]: copypaste: 25.7599,53.0174,28.0273,6.2718,26.6099,25.6551
# @@@ Evaluation @@@ 239
# [08/18 14:32:59 d2.utils.events]:  eta: 0:35:18  iter: 239  total_loss: 1.480  loss_cls: 0.332  loss_box_reg: 0.545  loss_mask: 0.292  loss_rpn_cls: 0.090  loss_rpn_loc: 0.251  validation_loss: 1.804  time: 0.4450  data_time: 0.0029  lr: 0.000122  max_mem: 4260M
# [08/18 14:33:10 d2.utils.events]:  eta: 0:34:52  iter: 259  total_loss: 1.538  loss_cls: 0.334  loss_box_reg: 0.539  loss_mask: 0.290  loss_rpn_cls: 0.086  loss_rpn_loc: 0.228  validation_loss: 1.804  time: 0.4427  data_time: 0.0044  lr: 0.000134  max_mem: 4260M
# [08/18 14:33:19 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:33:19 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:33:19 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:33:19 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:33:26 d2.evaluation.evaluator]: Inference done 11/14. 0.1180 s / img. ETA=0:00:02
# [08/18 14:33:27 d2.evaluation.evaluator]: Total inference time: 0:00:05.300616 (0.588957 s / img per device, on 1 devices)
# [08/18 14:33:27 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:01 (0.111161 s / img per device, on 1 devices)
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.434
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.718
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.227
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.115
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 43.387 | 71.804 | 45.556 | 22.708 | 46.231 | 41.880 |
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 75.834 | Deformed   | 48.578 | Death      | 37.328 |
# | Yolk       | 11.809 |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.595
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.329
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.287
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.333
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 28.992 | 59.523 | 32.854 | 10.462 | 29.363 | 28.738 |
# [08/18 14:33:27 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP    |
# |:-----------|:-------|:-----------|:-------|:-----------|:------|
# | Healthy    | 56.122 | Deformed   | 42.865 | Death      | 8.802 |
# | Yolk       | 8.180  |            |        |            |       |
# [08/18 14:33:27 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: 43.3872,71.8043,45.5555,22.7077,46.2311,41.8802
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:33:27 d2.evaluation.testing]: copypaste: 28.9924,59.5231,32.8535,10.4623,29.3631,28.7384
# @@@ Evaluation @@@ 279
# [08/18 14:33:29 d2.utils.events]:  eta: 0:34:41  iter: 279  total_loss: 1.547  loss_cls: 0.317  loss_box_reg: 0.526  loss_mask: 0.293  loss_rpn_cls: 0.090  loss_rpn_loc: 0.246  validation_loss: 1.744  time: 0.4423  data_time: 0.0030  lr: 0.000148  max_mem: 4260M
# [08/18 14:33:38 d2.utils.events]:  eta: 0:34:30  iter: 299  total_loss: 1.433  loss_cls: 0.301  loss_box_reg: 0.517  loss_mask: 0.279  loss_rpn_cls: 0.077  loss_rpn_loc: 0.235  validation_loss: 1.744  time: 0.4415  data_time: 0.0028  lr: 0.000162  max_mem: 4260M
# [08/18 14:33:47 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:33:47 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 14:33:47 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 14:33:47 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 14:33:53 d2.evaluation.evaluator]: Inference done 11/14. 0.1146 s / img. ETA=0:00:01
# [08/18 14:33:54 d2.evaluation.evaluator]: Total inference time: 0:00:04.795332 (0.532815 s / img per device, on 1 devices)
# [08/18 14:33:54 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.109053 s / img per device, on 1 devices)
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.715
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.547
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 42.838 | 71.540 | 46.556 | 16.995 | 46.252 | 41.936 |
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 75.777 | Deformed   | 50.063 | Death      | 36.357 |
# | Yolk       | 9.154  |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.335
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.442
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.369
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 30.670 | 60.339 | 33.531 | 7.637 | 32.733 | 30.927 |
# [08/18 14:33:54 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 57.979 | Deformed   | 45.909 | Death      | 11.445 |
# | Yolk       | 7.346  |            |        |            |        |
# [08/18 14:33:54 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: 42.8377,71.5395,46.5562,16.9955,46.2523,41.9358
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 14:33:54 d2.evaluation.testing]: copypaste: 30.6698,60.3391,33.5311,7.6369,32.7327,30.9270
# @@@ Evaluation @@@ 319
# [08/18 14:34:01 d2.utils.events]:  eta: 0:34:18  iter: 319  total_loss: 1.523  loss_cls: 0.334  loss_box_reg: 0.526  loss_mask: 0.279  loss_rpn_cls: 0.091  loss_rpn_loc: 0.245  validation_loss: 1.709  time: 0.4412  data_time: 0.0031  lr: 0.000177  max_mem: 4260M
# [08/18 14:34:12 d2.utils.events]:  eta: 0:34:06  iter: 339  total_loss: 1.395  loss_cls: 0.298  loss_box_reg: 0.515  loss_mask: 0.274  loss_rpn_cls: 0.068  loss_rpn_loc: 0.195  validation_loss: 1.709  time: 0.4400  data_time: 0.0045  lr: 0.000192  max_mem: 4260M
# [08/18 14:34:21 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 14:34:21 d2.data.common]: Serialized dataset takes 0.14 MiB
# ...
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.590
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.666
# [08/18 15:26:14 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 56.226 | 83.669 | 60.679 | 41.829 | 66.946 | 57.811 |
# [08/18 15:26:14 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 79.070 | Deformed   | 52.894 | Death      | 40.071 |
# | Yolk       | 52.868 |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.803
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.514
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
# [08/18 15:26:14 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 45.514 | 80.287 | 51.412 | 40.282 | 48.131 | 49.890 |
# [08/18 15:26:14 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 60.356 | Deformed   | 45.672 | Death      | 21.745 |
# | Yolk       | 54.284 |            |        |            |        |
# [08/18 15:26:14 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: 56.2257,83.6693,60.6792,41.8288,66.9459,57.8112
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:26:14 d2.evaluation.testing]: copypaste: 45.5141,80.2870,51.4116,40.2820,48.1315,49.8904
# @@@ Evaluation @@@ 4919
# [08/18 15:26:16 d2.utils.events]:  eta: 0:00:34  iter: 4919  total_loss: 0.729  loss_cls: 0.150  loss_box_reg: 0.272  loss_mask: 0.169  loss_rpn_cls: 0.019  loss_rpn_loc: 0.133  validation_loss: 0.981  time: 0.4319  data_time: 0.0025  lr: 0.000004  max_mem: 4260M
# [08/18 15:26:25 d2.utils.events]:  eta: 0:00:25  iter: 4939  total_loss: 0.757  loss_cls: 0.134  loss_box_reg: 0.290  loss_mask: 0.169  loss_rpn_cls: 0.021  loss_rpn_loc: 0.124  validation_loss: 0.981  time: 0.4318  data_time: 0.0026  lr: 0.000003  max_mem: 4260M
# [08/18 15:26:33 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 15:26:33 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 15:26:33 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 15:26:34 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 15:26:36 d2.evaluation.evaluator]: Inference done 11/14. 0.0866 s / img. ETA=0:00:00
# [08/18 15:26:37 d2.evaluation.evaluator]: Total inference time: 0:00:01.742815 (0.193646 s / img per device, on 1 devices)
# [08/18 15:26:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.085085 s / img per device, on 1 devices)
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.585
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.668
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.657
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 55.703 | 83.835 | 58.516 | 42.585 | 66.751 | 57.275 |
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 78.851 | Deformed   | 53.063 | Death      | 38.209 |
# | Yolk       | 52.691 |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.03 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.794
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 45.402 | 79.363 | 51.820 | 40.562 | 48.161 | 49.399 |
# [08/18 15:26:37 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 60.404 | Deformed   | 45.055 | Death      | 21.718 |
# | Yolk       | 54.430 |            |        |            |        |
# [08/18 15:26:37 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: 55.7034,83.8350,58.5158,42.5849,66.7509,57.2755
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:26:37 d2.evaluation.testing]: copypaste: 45.4017,79.3627,51.8197,40.5616,48.1607,49.3986
# @@@ Evaluation @@@ 4959
# [08/18 15:26:44 d2.utils.events]:  eta: 0:00:17  iter: 4959  total_loss: 0.703  loss_cls: 0.127  loss_box_reg: 0.263  loss_mask: 0.161  loss_rpn_cls: 0.016  loss_rpn_loc: 0.138  validation_loss: 0.981  time: 0.4318  data_time: 0.0027  lr: 0.000002  max_mem: 4260M
# [08/18 15:26:55 d2.utils.events]:  eta: 0:00:08  iter: 4979  total_loss: 0.821  loss_cls: 0.146  loss_box_reg: 0.296  loss_mask: 0.171  loss_rpn_cls: 0.026  loss_rpn_loc: 0.148  validation_loss: 0.981  time: 0.4318  data_time: 0.0042  lr: 0.000002  max_mem: 4260M
# [08/18 15:27:04 d2.data.common]: Serializing 14 elements to byte tensors and concatenating them all ...
# [08/18 15:27:04 d2.data.common]: Serialized dataset takes 0.14 MiB
# [08/18 15:27:04 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/18 15:27:04 d2.evaluation.evaluator]: Start inference on 14 images
# [08/18 15:27:07 d2.evaluation.evaluator]: Inference done 11/14. 0.0840 s / img. ETA=0:00:00
# [08/18 15:27:08 d2.evaluation.evaluator]: Total inference time: 0:00:01.699169 (0.188797 s / img per device, on 1 devices)
# [08/18 15:27:08 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.083030 s / img per device, on 1 devices)
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Saving results to ./outputs/new_dataset/res101_fr2_no_problamatic_5000_random_zoom_with_Yolk/inference/coco_instances_results.json
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.836
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.663
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 55.723 | 83.626 | 58.238 | 42.529 | 66.601 | 57.085 |
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 78.690 | Deformed   | 53.278 | Death      | 38.209 |
# | Yolk       | 52.713 |            |        |            |        |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.802
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.478
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.618
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 45.373 | 80.230 | 51.812 | 40.617 | 47.822 | 49.515 |
# [08/18 15:27:08 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Healthy    | 60.459 | Deformed   | 44.873 | Death      | 21.718 |
# | Yolk       | 54.442 |            |        |            |        |
# [08/18 15:27:08 d2.engine.defaults]: Evaluation results for val_collapsed in csv format:
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: Task: bbox
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: 55.7227,83.6263,58.2379,42.5290,66.6010,57.0846
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: Task: segm
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [08/18 15:27:08 d2.evaluation.testing]: copypaste: 45.3732,80.2296,51.8121,40.6166,47.8225,49.5149
# @@@ Evaluation @@@ 4999
# [08/18 15:27:15 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.670  loss_cls: 0.122  loss_box_reg: 0.254  loss_mask: 0.161  loss_rpn_cls: 0.027  loss_rpn_loc: 0.120  validation_loss: 0.981  time: 0.4318  data_time: 0.0028  lr: 0.000002  max_mem: 4260M
# [08/18 15:27:17 d2.engine.hooks]: Overall training speed: 4997 iterations in 0:35:58 (0.4319 s / it)
# [08/18 15:27:17 d2.engine.hooks]: Total training time: 0:57:33 (0:21:35 on hooks)

# %%
trainer.model
# Out:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (predictor): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
